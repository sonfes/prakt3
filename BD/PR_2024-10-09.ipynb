-- %% [markdown]
-- # [Sonya_Subocheva_2024-10-09]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Sonya_Subocheva_2024-10-09]    Script Date: 09.10.2024 15:31:49 ******/
CREATE DATABASE [Sonya_Subocheva_2024-10-09]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Sonya_Subocheva_2024-10-09', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Sonya_Subocheva_2024-10-09.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Sonya_Subocheva_2024-10-09_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\Sonya_Subocheva_2024-10-09_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Sonya_Subocheva_2024-10-09].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET ARITHABORT OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET  MULTI_USER 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET QUERY_STORE = ON
GO
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Budget]

-- %%
USE [Sonya_Subocheva_2024-10-09]
GO

-- %%
/****** Object:  Table [dbo].[Budget]    Script Date: 09.10.2024 15:31:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Budget](
	[Expenses] [int] NULL,
	[Income] [int] NULL,
	[Amount_budget] [int] NOT NULL,
	[ID] [int] NOT NULL,
	[Source] [text] NOT NULL,
	[Total_Amount] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [PK_Budget] PRIMARY KEY CLUSTERED 
(
	[Total_Amount] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User]

-- %%
/****** Object:  Table [dbo].[User]    Script Date: 09.10.2024 15:31:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User](
	[Name] [text] NOT NULL,
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Password] [text] NOT NULL,
 CONSTRAINT [PK_User] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [Sonya_Subocheva_2024-10-09]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Sonya_Subocheva_2024-10-09] SET  READ_WRITE 
GO
